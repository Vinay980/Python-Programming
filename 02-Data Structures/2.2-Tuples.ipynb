# %% [markdown]
# ### Tuples
#
# Tuples are ordered collections of items that are immutable. They are similar to lists, but their immutability makes them different.

# %%
tuple = ()
print(tuple)
print(type(tuple))
# Out:
# ()
# <class 'tuple'>

# %%
lst=list()
print(type(lst))
tpl=()
print(type(tpl))
# Out:
# <class 'list'>
# <class 'tuple'>

# %% [markdown]
# ### in tuple and list coersion happens

# %%
tpl= ([1,2,3])
print(tpl)
list((1,2,3))
# Out:
# [1, 2, 3]
# [1, 2, 3]

# %%
# Accessing of Tuple element

tpl
# Out:
# [1, 2, 3]

# %%
tpl[2]
# Out:
# 3

# %%
tpl[0:2]
# Out:
# [1, 2]

# %%
# for reversing the tuple
tpl[::-1]
# Out:
# [3, 2, 1]
