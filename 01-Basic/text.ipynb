# %%
print("hello")
# Out:
# hello

# %%
print("h")
print("hello")
# Out:
# h
# hello

# %%
year=int(input("Enter the year: "))
if year%4==0:
    print(f"{year}this is leap year")
    if year%100==0:
        print(f"{year}this is leap year")
        if year%400==0:
            print(f"{year}this is leap year")
        else:
            print(f"{year}this is not a leap year")
    else:
            print(f"{year}this is not a leap year")
else:
            print(f"{year}this is not a leap year")
# Out:
# 2020this is leap year
# 2020this is not a leap year

# %%
num1=float(input("Enter any number: "))
num2=float(input("Enter any number: "))
operation=input('Enter operation(+,-,*,/):')

if operation=="+":
    result=num1+num2
elif operation=="-":
    result=num1-num2
elif operation=='*':
    result=num1*num2
elif operation=="/":
    result=num1/num2
else:
    result= "Invalid"
    
print("Result: ",result)
# Out:
# Result:  25.0

# %%
n=1
sum=0
count=1
while count<=10:
    sum=count+sum
    count +=1

print(sum)
# Out:
# 55

# %%
sum=0
n=1
for i in range(10):
    sum=sum+i
    
print(sum)
# Out:
# 45

# %%
a=5
b=a
c=0
id(a)
id(b)
# Out:
# 140715324099128

# %%
id(b)
# Out:
# 140715324099128

# %%
id(b)
# Out:
# 140715324099128

# %%
a="Hello"
b=a
c=b
a
# Out:
# 'Hello'

# %%
b
# Out:
# 'Hello'

# %%
c
# Out:
# 'Hello'
